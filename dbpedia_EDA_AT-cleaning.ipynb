# %%
try:
    import pandas as pd
    import numpy as np
    import csv
    import json
    import os
    import matplotlib.pyplot as plt

    
except Exception as E:
    print('Some modules are missing')

# %% [markdown]
# ## Goal -> Keep only 1st type and obtain rest using SPARQL. -> Obtain Accuracy

# %%
# !ls ../smart-2022-datasets/
# Out:
# AT_answer_type_prediction  LICENSE    RL_relation_linking
# EL_entity_linking	   README.md

# %%
path = '/home/hitachi/Desktop/submission/smart-dataset/datasets/DBpedia/smarttask_dbpedia_test.json'

# %%
at_db_test_fpath = os.path.join(path)

# %%
with open(at_db_test_fpath, 'r') as f:
    at_db_test = json.load(f)

# %%
len(at_db_test)
# Out:
# 4381

# %%
at_db_test
# Out:
# [{'id': 'dbpedia_16015',
#   'question': 'How many ingredients are in the grain} ?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_3885',
#   'question': 'Is the case fatality rate of Fournier gangrene fewer than 9.0?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_12907',
#   'question': 'Does the shelf life of spinach equal 8?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_7955',
#   'question': 'What sound does a pig make in the French language?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_2376',
#   'question': 'When was Fergie completed his record label in Interscope records?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_4197',
#   'question': 'Which are the coordinates of easternmost point of Estonia?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_22599',
#   'question': 'Where did the war take place where one of the commander was Zuo Zongtang?',
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_5469',
#   'question': 'Was Michael Bloomberg a residence in Medford and Allston?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_687',
#   'question': 'How many platforms does Tomb Raider have?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_19677',
#   'question': 'Which mountains are contained in Inyo National Forest?',
#   'category': 'resource',
#   'type': ['dbo:Mountain', 'dbo:NaturalPlace', 'dbo:Place']},
#  {'id': 'dbpedia_15673',
#   'question': 'How many nominations did Lewis Hamilton receive?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_11163',
#   'question': 'What is the seat of Frankfurter Allgemeine Zeitung, that is adjacent to Wetteraukreis?',
#   'category': 'resource',
#   'type': ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_4173',
#   'question': "Is it true that the points awarded of the 2018 AFL Women's season equals to 2?",
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_18169',
#   'question': 'Is Microsoft office written in C++',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_10686',
#   'question': 'Was Carmelo Anthony nominated for BET Award for athlete of the year?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_5678',
#   'question': "What is Daniel Ellsberg's NYRB contributor ID?",
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_18792',
#   'question': 'What did the people buried in Toronto die of?',
#   'category': 'resource',
#   'type': ['dbo:Disease']},
#  {'id': 'dbpedia_5481',
#   'question': 'When did Alfred Dreyfus receive the award of Officer of the Legion of Honour?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_2013',
#   'question': "What is the Strait of Juan de Fuca's geographical ID?",
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_11251',
#   'question': 'What is the league of major league lacrosse?',
#   'category': 'resource',
#   'type': ['dbo:SportsTeam', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_17993',
#   'question': 'What series did Robert Guillaume play Robert?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_20546',
#   'question': 'Which political party of Arunachal Pradesh Legislative Assembly election, 2014 was the leader of Rishikesh ?',
#   'category': 'resource',
#   'type': ['dbo:PoliticalParty']},
#  {'id': 'dbpedia_17589',
#   'question': "What is Janet Jackson's genre?",
#   'category': 'resource',
#   'type': ['dbo:MusicGenre', 'dbo:Genre', 'dbo:TopicalConcept']},
#  {'id': 'dbpedia_10307',
#   'question': 'What are the public company which start with the letter t',
#   'category': 'resource',
#   'type': ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_865',
#   'question': 'How much acreage is the death place of Saul Bass?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_15502',
#   'question': 'Which trans-Neptunian object has the most argument of periapsis?',
#   'category': 'resource',
#   'type': ['dbo:Asteroid', 'dbo:CelestialBody', 'dbo:Place']},
#  {'id': 'dbpedia_2096',
#   'question': 'Which Chinese Han that studied engineering has the lowest estimated net worth?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_15898',
#   'question': 'Which is the operating system that has Assembly language as a programming language and which starts with the letter v?',
#   'category': 'resource',
#   'type': ['dbo:Software', 'dbo:Work']},
#  {'id': 'dbpedia_11557',
#   'question': 'Does the scale of the HO scale equal 87?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_18447',
#   'question': 'Which composer of Girl from the North Country is the subsequent work of the Moondog Matinee?',
#   'category': 'resource',
#   'type': ['dbo:MusicalArtist', 'dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_20324',
#   'question': 'How many things do bridges designed by the UEM group go over?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_21857',
#   'question': 'Where does the river end, into which the Rakitnica flows?',
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_20790',
#   'question': 'How did Letitia MacTavish Hargrave died ?',
#   'category': 'resource',
#   'type': ['dbo:Disease']},
#  {'id': 'dbpedia_17145',
#   'question': 'What is the sibling of John III Sobieski employed as?',
#   'category': 'resource',
#   'type': ['dbo:Profession', 'dbo:PersonFunction']},
#  {'id': 'dbpedia_20450',
#   'question': 'What is the regional radio sports network associated with?',
#   'category': 'resource',
#   'type': ['dbo:AmericanFootballTeam',
#    'dbo:SoccerClub',
#    'dbo:SportsTeam',
#    'dbo:Organisation',
#    'dbo:Agent']},
#  {'id': 'dbpedia_18827',
#   'question': 'List TV shows with producer as Erik Bork and company is DreamWorks Television ?',
#   'category': 'resource',
#   'type': ['dbo:Film', 'dbo:TelevisionShow', 'dbo:Work']},
#  {'id': 'dbpedia_20582',
#   'question': 'How many universities are in the National Collegiate Athletic Association?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_6724',
#   'question': "What was William Shakespeare's occupation?",
#   'category': 'resource',
#   'type': ['dbo:Profession', 'dbo:PersonFunction']},
#  {'id': 'dbpedia_17542',
#   'question': 'What are the gravitational-wave detector which start with the letter v',
#   'category': 'resource',
#   'type': ['dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_12072',
#   'question': "What is Michael Faraday's EGAXA ID?",
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_7166',
#   'question': 'Name the Sparkasse with highest tier 1 capital ratio?',
#   'category': 'resource',
#   'type': ['dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_15701',
#   'question': 'What college town is located in UTC time zone and starts with the letter Z.',
#   'category': 'resource',
#   'type': ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_16236',
#   'question': 'What is the population of the province where the Kunsthistorisches Museum is located?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_2904',
#   'question': 'What is the genetic association of the regulates (molecular biology) of the hsa-miR-6887-5p?',
#   'category': 'resource',
#   'type': ['dbo:Disease']},
#  {'id': 'dbpedia_6065',
#   'question': 'What is the number of out of school children of the continent of Kagera River ?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_13035',
#   'question': 'Tell me intelligence agency whose name has the word stations in it.',
#   'category': 'resource',
#   'type': ['dbo:GovernmentAgency', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_3743',
#   'question': 'What is {portrayed by} {track listing} of {Invasion of Privacy} ?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_11441',
#   'question': 'Tell me magazine whose name has the word zillo in it.',
#   'category': 'resource',
#   'type': ['dbo:Magazine',
#    'dbo:PeriodicalLiterature',
#    'dbo:WrittenWork',
#    'dbo:Work']},
#  {'id': 'dbpedia_21275',
#   'question': 'Is facebook a public company?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_2169',
#   'question': 'Who is {nominated for} of {Kate Winslet} whose {for work} is {Sense and Sensibility} ?',
#   'category': 'resource',
#   'type': ['dbo:Award']},
#  {'id': 'dbpedia_8309',
#   'question': 'Chemical compounds are studied in what branch of science?',
#   'category': 'resource',
#   'type': ['dbo:AcademicSubject', 'dbo:TopicalConcept']},
#  {'id': 'dbpedia_14696',
#   'question': 'Name a member of the Nazi Party.',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_6686',
#   'question': 'Was Ricky_Martin genre reggae  and beat music?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_8477',
#   'question': 'What is the production date for The Barber of Seville?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_20621',
#   'question': 'What is the river on which the Kariba Dam and Batoka Gorge Hydroelectirc power station exist?',
#   'category': 'resource',
#   'type': ['dbo:River',
#    'dbo:Stream',
#    'dbo:BodyOfWater',
#    'dbo:NaturalPlace',
#    'dbo:Place']},
#  {'id': 'dbpedia_13081',
#   'question': 'Who is the painter of the work described by Markko Rivera?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_11342',
#   'question': 'What is causing Ada to lose her dialect?',
#   'category': 'resource',
#   'type': ['dbo:ProgrammingLanguage', 'dbo:Language']},
#  {'id': 'dbpedia_1610',
#   'question': 'Which presidential election had the most eligible voters?',
#   'category': 'resource',
#   'type': ['dbo:Election', 'dbo:SocietalEvent', 'dbo:Event']},
#  {'id': 'dbpedia_5531',
#   'question': 'What is the speed of sound of liquid mercury?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_22145',
#   'question': 'Name the team which is owned by Dafenham wind turbines and stood first in 1967 mexican Grand Prix ?',
#   'category': 'resource',
#   'type': ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_5991',
#   'question': 'What is the anatomically connects with the esophagus',
#   'category': 'resource',
#   'type': ['dbo:AnatomicalStructure']},
#  {'id': 'dbpedia_20965',
#   'question': 'Did Stan Lee write the Daredevils?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_9328',
#   'question': 'What was the death place of Max Miedinger, which was divided into District 7?',
#   'category': 'resource',
#   'type': ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_17196',
#   'question': 'What is the Lemon 64 identifier of Frogger?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_17597',
#   'question': 'Who is the person as the head of government of Lviv?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_8151',
#   'question': 'n/a',
#   'category': 'resource',
#   'type': ['dbo:Film', 'dbo:Work']},
#  {'id': 'dbpedia_1645',
#   'question': 'Is the standard enthalpy of formation for ethanol less than -333.12?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_21999',
#   'question': 'List all the mmebers of  Mekong River Commission?',
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_22136',
#   'question': 'Was John muir one of the first to ascend a mountain on Mt hoffmann?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_12376',
#   'question': 'What is it?',
#   'category': 'resource',
#   'type': ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_21435',
#   'question': 'How many teams have LA kings players in them currently?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_18496',
#   'question': 'What academic discipline of the Journal of Cerebral Blood Flow & Metabolism is also the record label of the Double Diamond (album)?',
#   'category': 'resource',
#   'type': ['dbo:Brain', 'dbo:AnatomicalStructure']},
#  {'id': 'dbpedia_19727',
#   'question': "Which university's graduates have worked in the Quartermaster corps?",
#   'category': 'resource',
#   'type': ['dbo:University',
#    'dbo:EducationalInstitution',
#    'dbo:Organisation',
#    'dbo:Agent']},
#  {'id': 'dbpedia_20944',
#   'question': 'List all the teams which have someone who played their first game for the Yankees?',
#   'category': 'resource',
#   'type': ['dbo:BaseballTeam',
#    'dbo:SportsTeam',
#    'dbo:Organisation',
#    'dbo:Agent']},
#  {'id': 'dbpedia_20180',
#   'question': 'Who is the cover artist of Doctor Mirabilis (novel) ?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_8843',
#   'question': 'who is excavation director of Assur ?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_1051',
#   'question': 'Which is the ComicBookDB ID for Warren Ellis?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_6930',
#   'question': 'Is Mario Puzo the screenwriter of The Godfather?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_16217',
#   'question': 'What borders the lake of Alimia?',
#   'category': 'resource',
#   'type': ['dbo:Archipelago', 'dbo:NaturalPlace', 'dbo:Place']},
#  {'id': 'dbpedia_9441',
#   'question': 'What is the local dialing code for Melbourne?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_10394',
#   'question': 'Which nonprofit organization has the largest member count?',
#   'category': 'resource',
#   'type': ['dbo:Non-ProfitOrganisation', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_20499',
#   'question': 'List the websites which the authors of Tornado own ?',
#   'category': 'resource',
#   'type': ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_15198',
#   'question': 'Is it true that the employment by economic sector of Amsterdam is 12250?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_1201',
#   'question': "Which is the association of the chairperson Thomas Bach that contains the word committee in it's name?",
#   'category': 'resource',
#   'type': ['dbo:Non-ProfitOrganisation', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_539',
#   'question': 'Is Mary I of England a sibling of Edward VI of England?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_18580',
#   'question': 'Which fictional character portrayed by Roger barton has Padm Amidala as family ?',
#   'category': 'resource',
#   'type': ['dbo:FictionalCharacter', 'dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_11754',
#   'question': 'In what year did Martha Argerich marry Stephen Kovacevich?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_12509',
#   'question': 'What is the ProCyclingStats cyclist ID for Greg LeMond',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_3527',
#   'question': 'What Wikimedia article lists the monuments of Bern?',
#   'category': 'resource',
#   'type': ['dbo:Media']},
#  {'id': 'dbpedia_15115',
#   'question': 'Which is the organization that is member of Auburn University?',
#   'category': 'resource',
#   'type': ['dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_4528',
#   'question': 'what are studio album starts with the letter w',
#   'category': 'resource',
#   'type': ['dbo:Album', 'dbo:MusicalWork', 'dbo:Work']},
#  {'id': 'dbpedia_6357',
#   'question': 'who is the {mother} for {Will Smith} that has {child} as {Willow Smith} ?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_22921',
#   'question': 'Whos a famous relative of anne spielberg?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_12974',
#   'question': 'What is the headwater on the river of Kodiak Island?',
#   'category': 'resource',
#   'type': ['dbo:River',
#    'dbo:Stream',
#    'dbo:BodyOfWater',
#    'dbo:NaturalPlace',
#    'dbo:Place']},
#  {'id': 'dbpedia_15288',
#   'question': 'Does the ionization energy of the iodine equal 9.31?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_11098',
#   'question': 'Which is the Lives of WWI ID for Anthony Eden?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_9367',
#   'question': 'Which passenger ship has the longest draft?',
#   'category': 'resource',
#   'type': ['dbo:Ship', 'dbo:MeanOfTransportation']},
#  {'id': 'dbpedia_18939',
#   'question': 'Which are the races in which Martin Molony participated?',
#   'category': 'resource',
#   'type': ['dbo:HorseRace',
#    'dbo:Race',
#    'dbo:SportsEvent',
#    'dbo:SocietalEvent',
#    'dbo:Event']},
#  {'id': 'dbpedia_15841',
#   'question': "What is Ayn Rand's Ban Q author ID?",
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_1824',
#   'question': 'Does the number of injured of the Monbar Hotel attack equals 1?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_13440',
#   'question': 'When did Martha Graham graduate from Denishawn School of Dancing and Related Arts?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_16430',
#   'question': 'Which is the NOC Occupation Code for truck driver?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_848',
#   'question': 'What is PACE member ID for James Callaghan ?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_23201',
#   'question': 'What is the most frequent cause of death?',
#   'category': 'resource',
#   'type': ['dbo:Disease']},
#  {'id': 'dbpedia_3865',
#   'question': 'What number of households did a census, as a determination method, find in Tifariti?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_6892',
#   'question': 'Who is the relative of the Faisal of Saudi Arabia?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_3331',
#   'question': 'How much people are there in the  administrative territorial entity of Madeira?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_702',
#   'question': 'Who are Sandrart.net artwork ID of Laocoön and His Sons?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_10585',
#   'question': 'Anatoly Karpov has how many title of chess players',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_8002',
#   'question': "What is the European Union's legislative body and its highest judicial authority?",
#   'category': 'resource',
#   'type': ['dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_18653',
#   'question': 'What is the television show whose judges is Randy Jackson?',
#   'category': 'resource',
#   'type': ['dbo:TelevisionShow', 'dbo:Work']},
#  {'id': 'dbpedia_22392',
#   'question': 'Does Cascade Airways have a hub in Seattle?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_20972',
#   'question': 'How many Thesaban towns are there?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_13276',
#   'question': 'What prescribed drug is the cause of death of Robert Menzies?',
#   'category': 'resource',
#   'type': ['dbo:ChemicalCompound', 'dbo:ChemicalSubstance']},
#  {'id': 'dbpedia_4897',
#   'question': 'who is executive producer of Bicycle Thieves ?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_12655',
#   'question': 'Is the flux of Abell 1689 equal to 0.00000000014729?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_21184',
#   'question': 'Why did Letita McTavish Hargrave and Sextus Barbour die?',
#   'category': 'resource',
#   'type': ['dbo:Disease']},
#  {'id': 'dbpedia_5424',
#   'question': "What diplomatic relation of Mauritius was the location of Daniel Dunglas Home's death?",
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_12705',
#   'question': 'For what did Claude Chabrol receive the Louis Delluc Prize?',
#   'category': 'resource',
#   'type': ['dbo:Film', 'dbo:Work']},
#  {'id': 'dbpedia_3240',
#   'question': 'What Class IIIB combustible liquid has the highest vapor pressure?',
#   'category': 'resource',
#   'type': ['dbo:ChemicalCompound', 'dbo:ChemicalSubstance']},
#  {'id': 'dbpedia_5736',
#   'question': 'Which is the radius of Earth?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_183',
#   'question': "What is a sovereign state for office held by the pope's head of state?",
#   'category': 'resource',
#   'type': ['dbo:Country',
#    'dbo:City',
#    'dbo:State',
#    'dbo:Settlement',
#    'dbo:PopulatedPlace',
#    'dbo:Place']},
#  {'id': 'dbpedia_19905',
#   'question': 'In which mountain range does the Rochers De Naye lie?',
#   'category': 'resource',
#   'type': ['dbo:MountainRange', 'dbo:NaturalPlace', 'dbo:Place']},
#  {'id': 'dbpedia_671',
#   'question': 'Which is the AlloCiné person ID for Leslie Howard?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_4461',
#   'question': 'Does the Independent have a publication interval that is equal to 1.2?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_22987',
#   'question': 'Name books with publisher as Francisco de Robles and writer as Miguel de Cervantes ?',
#   'category': 'resource',
#   'type': ['dbo:Book', 'dbo:WrittenWork', 'dbo:Work']},
#  {'id': 'dbpedia_5924',
#   'question': 'What is the post of Clement Attlee and when he was sworn in?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_19549',
#   'question': 'who are the managers of england national under 20 football team?',
#   'category': 'resource',
#   'type': ['dbo:SoccerManager',
#    'dbo:SportsManager',
#    'dbo:SoccerPlayer',
#    'dbo:Person',
#    'dbo:Agent']},
#  {'id': 'dbpedia_8646',
#   'question': 'For which disease aspirin is being used?',
#   'category': 'resource',
#   'type': ['dbo:Disease']},
#  {'id': 'dbpedia_1673',
#   'question': 'What is the Terminologia Histologica for stem cell?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_18238',
#   'question': 'Which Fox  show is presented by Ryan Seacrest?',
#   'category': 'resource',
#   'type': ['dbo:TelevisionShow', 'dbo:Work']},
#  {'id': 'dbpedia_3263',
#   'question': 'How many presenters are for Top Gear?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_14411',
#   'question': "Where is Bjørnstjerne Bjørnson's burial plot in Vår Frelsers gravlund?",
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_3994',
#   'question': 'Did Muawiyah I die before 1584?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_8652',
#   'question': 'who is film starring of un chien andalou that has his father is salvador dali i cusi',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_17',
#   'question': 'How many dimensions have a Captain America?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_15760',
#   'question': 'Name the publisher of Playboy',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_9621',
#   'question': 'What is the World Health Organisation International Nonproprietary Name for nitric oxide radical ?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_1803',
#   'question': 'When Anna Netrebko was awarded State Prize of the Russian Federation?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_3066',
#   'question': 'What is the diplomatic relation between Tunisia and its official language Tuvan?',
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_10108',
#   'question': 'What is signed by the sister society of Nat Simons?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_11951',
#   'question': 'Where is the place of death of John Stuart Mill, that is also a sister city of Ioannina?',
#   'category': 'resource',
#   'type': ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_6872',
#   'question': 'In the tetrahedral group, does the cardinality of the group equal to 14.4?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_1118',
#   'question': 'Is it true that the term length of office of Captain Regent of San Marino equals to 0.5?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_3529',
#   'question': "Who are Sean Connery's wife and child?",
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_14136',
#   'question': 'is it true that the observing time available of the kitt peak national observatory is greater than 312?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_12827',
#   'question': "What was the name of Thomas Jefferson's plantation?",
#   'category': 'resource',
#   'type': ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_2452',
#   'question': 'What are the instructions for x86?',
#   'category': 'resource',
#   'type': ['dbo:ProgrammingLanguage', 'dbo:Language']},
#  {'id': 'dbpedia_19213',
#   'question': 'What is the political party of the of Bengalis ?',
#   'category': 'resource',
#   'type': ['dbo:PoliticalParty']},
#  {'id': 'dbpedia_13563',
#   'question': 'How is cheese pronounced in Czech?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_23102',
#   'question': 'Which subsidiary of TUI Travel serves both Glasgow and Dublin?',
#   'category': 'resource',
#   'type': ['dbo:Airline', 'dbo:Company', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_20082',
#   'question': 'What is the common debut team of the Butch Metzger and Dan Otero?',
#   'category': 'resource',
#   'type': ['dbo:BaseballTeam',
#    'dbo:SportsTeam',
#    'dbo:Organisation',
#    'dbo:Agent']},
#  {'id': 'dbpedia_13561',
#   'question': 'Which is Finnish Lake ID for Saimaa?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_13491',
#   'question': 'When did Greg LeMond start playing for the Z team?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_15307',
#   'question': 'What gene is genetically associated with colorectal cancer',
#   'category': 'resource',
#   'type': ['dbo:Gene', 'dbo:Biomolecule']},
#  {'id': 'dbpedia_19674',
#   'question': 'Name the place of Qaqun ?',
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_10691',
#   'question': '?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_6007',
#   'question': 'What is the FAA airport code for Los Angeles International Airport?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_3815',
#   'question': 'Who is the writer of Cloud Atlas that has a last name of Mitchell?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_17450',
#   'question': 'What is the refractive index for water?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_17575',
#   'question': 'What nomination  received from Bradley Cooper having victor as Robert Donat?',
#   'category': 'resource',
#   'type': ['dbo:Award']},
#  {'id': 'dbpedia_20628',
#   'question': 'How many things are people who died in St. Petersburg known for?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_19633',
#   'question': 'Which country of Montaas Mayas Chiquibul is the birth place of Jos Bernardo Escobar?',
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_4317',
#   'question': 'When did Fredrich Bessel win the Gold Medal of the Royal Astronomical Society?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_14301',
#   'question': 'What was designed by Pascal, who was a member of the Academia Europaea?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_21450',
#   'question': 'What are other famous works of the writer who created the Sarah Jane Adventures?',
#   'category': 'resource',
#   'type': ['dbo:TelevisionShow', 'dbo:Work']},
#  {'id': 'dbpedia_988',
#   'question': 'When did Reinhard Heydrich stop being the President of Interpol?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_18265',
#   'question': 'What is the total number of other non-fiction subject of the books whose one of the subject is Racism?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_15086',
#   'question': 'For which work did Graham Kennedy receive a Gold Logie Award for Most Popular Personality on Australian Television?',
#   'category': 'resource',
#   'type': ['dbo:TelevisionShow', 'dbo:Work']},
#  {'id': 'dbpedia_15202',
#   'question': 'Does Elizabeth Taylor speak Icelandic?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_9494',
#   'question': 'When did Cuiaba become part of Mato Grosso ?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_13088',
#   'question': 'Name the taxon with the lowest generation time whose instance of taxon?',
#   'category': 'resource',
#   'type': ['dbo:Taxon', 'dbo:TopicalConcept']},
#  {'id': 'dbpedia_11873',
#   'question': 'Was Billy the kid a cowboy and an outlaw?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_13022',
#   'question': 'Who was born at with Alexander Karelin which has twin town in Minneapolis?',
#   'category': 'resource',
#   'type': ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_7186',
#   'question': 'What took place at the Fortress Besieged, with Myanmar diplomatic relations?',
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_15955',
#   'question': "When did Rowan Atkinson attend the Queen's College?",
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_9296',
#   'question': 'Which is the density of malathion?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_14762',
#   'question': 'When did Leon Lai and Gaile Lok marry?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_9778',
#   'question': 'When did Woody Guthrie receive the Grammy Lifetime Achievement Award?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_7787',
#   'question': 'Who is the {tennis event} for {victory} of {Rod Laver}',
#   'category': 'resource',
#   'type': ['dbo:Activity']},
#  {'id': 'dbpedia_9131',
#   'question': 'Which space station has completed maximum orbits?',
#   'category': 'resource',
#   'type': ['dbo:SpaceStation', 'dbo:MeanOfTransportation']},
#  {'id': 'dbpedia_624',
#   'question': "Who is Nicole Richie's mother?",
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_22104',
#   'question': "Which country's leader  is Giuseppe Bertello?",
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_11371',
#   'question': 'Is the number of  blank votes of the Volta Redonda mayoral election of 2016 less than 5163.2',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_7295',
#   'question': 'Does the Giotto consume power equal to 196?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_8130',
#   'question': 'We were informed by Ben Okri that his hometown is in the Hercules Building that is right?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_15008',
#   'question': 'What is place in Würzburg is also known as roentgen?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_350',
#   'question': 'Which is Xeno-canto species ID for Meleagris gallopavo?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_5033',
#   'question': 'Which book is Hillary Clinton popular for?',
#   'category': 'resource',
#   'type': ['dbo:Book', 'dbo:WrittenWork', 'dbo:Work']},
#  {'id': 'dbpedia_17579',
#   'question': 'Is the vehicles per thousand people of Luxembourg equal to 662?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_15736',
#   'question': 'When did Vladimir Komarov receive the Hero of the Soviet Union award?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_17832',
#   'question': 'WHO IS THE SISTER OR BROTHER OF THE BAHAI FAITH FOUNDER?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_14101',
#   'question': 'Is the median lethal concentration of the dichlorine equal to 137?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_20589',
#   'question': 'What is the workplace of Christopher S. Stewart ?',
#   'category': 'resource',
#   'type': ['dbo:Newspaper',
#    'dbo:PeriodicalLiterature',
#    'dbo:WrittenWork',
#    'dbo:Work']},
#  {'id': 'dbpedia_14563',
#   'question': 'Which is the publisher of Through the Looking-Glass?',
#   'category': 'resource',
#   'type': ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_5915',
#   'question': 'What is the Gaming-history identifier of Xbox?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_10964',
#   'question': 'What science studies symmetry breaking?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_20263',
#   'question': 'What is the job of the George Arceneaux, Jr. which is also the office of the Blanche Bruce',
#   'category': 'resource',
#   'type': ['dbo:Legislature', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_10652',
#   'question': 'What work did Satyajit Ray receive the National Film Award for Best Non-Feature Film for ?',
#   'category': 'resource',
#   'type': ['dbo:Film', 'dbo:Work']},
#  {'id': 'dbpedia_17518',
#   'question': "Which of Joachim Murat's Kids wrote language in French?",
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_20480',
#   'question': 'How many guests have been there on broadway?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_19380',
#   'question': 'Which leader of Trump Entertainment Resorts is a relative of Maryanne Barry?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_388',
#   'question': 'Which French killer had the most victims ?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_3143',
#   'question': 'Is the angular resolution of the Karl G. Jansky Very Large Array equal to 0.2?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_7269',
#   'question': 'Is the nominal GDP of Ethiopia equal to 80561496133.9172?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_10866',
#   'question': 'Which is the Literature Ireland ID for John Banville?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_17932',
#   'question': 'What area is managed by Buckenham Marshes RSPB reserve',
#   'category': 'resource',
#   'type': ['dbo:Taxon', 'dbo:TopicalConcept']},
#  {'id': 'dbpedia_3078',
#   'question': 'Is the boiler pressure of the SNCF 141.R equal to 15.5?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_11988',
#   'question': 'What subordinate companies does Dassault of Rafale hold?',
#   'category': 'resource',
#   'type': ['dbo:MilitaryUnit', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_22595',
#   'question': 'What are the software whose programming language are Multilingual?',
#   'category': 'resource',
#   'type': ['dbo:Software', 'dbo:Work']},
#  {'id': 'dbpedia_12448',
#   'question': 'which means {Harvard designation} for{Sputnik 1} ?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_2745',
#   'question': 'Which is the tracklist for Revolver?',
#   'category': 'resource',
#   'type': ['dbo:Work']},
#  {'id': 'dbpedia_5561',
#   'question': 'who is the father and child of Vince_McMahon?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_19930',
#   'question': 'AH141 highway is a part of which country?',
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_16931',
#   'question': 'Franklin Chang Diaz already made as many missions astronauts?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_4989',
#   'question': "What is FC Barcelona's parent club?",
#   'category': 'resource',
#   'type': ['dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_21566',
#   'question': 'Name the television show whose company is HBO and Playtone?',
#   'category': 'resource',
#   'type': ['dbo:TelevisionShow', 'dbo:Film', 'dbo:Work']},
#  {'id': 'dbpedia_9117',
#   'question': 'What is the trademark of Barcelona, and where is their headquarters located?',
#   'category': 'resource',
#   'type': ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_12865',
#   'question': 'Was Ice-T with Ace of Hearts Records record label?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_18553',
#   'question': 'Gamini Seneviratne and Katyayana are two followers of which religion?',
#   'category': 'resource',
#   'type': ['dbo:Country']},
#  {'id': 'dbpedia_11474',
#   'question': "What are the characters of Joshua who is the deity of Jehovah's Witnesses?",
#   'category': 'resource',
#   'type': ['dbo:Name']},
#  {'id': 'dbpedia_6558',
#   'question': 'Who is the son- in- law of the co-founder of the Catholic Church?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_22533',
#   'question': 'How many golf players are there in Arizona State Sun Devils ?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_20440',
#   'question': 'Name the sea whose inflow is Kemijoki and outflow is Danish straits?',
#   'category': 'resource',
#   'type': ['dbo:Lake',
#    'dbo:Sea',
#    'dbo:BodyOfWater',
#    'dbo:NaturalPlace',
#    'dbo:Place']},
#  {'id': 'dbpedia_6847',
#   'question': 'Palauli forms part of the capital of Apia, give the complete place name.',
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_22037',
#   'question': 'Who owns the newspaper which was founded by Nehru?',
#   'category': 'resource',
#   'type': ['dbo:PoliticalParty']},
#  {'id': 'dbpedia_10471',
#   'question': "What is Die Hard's LdiF ID?",
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_4801',
#   'question': 'What town is near where Yi Sun-sin was born.',
#   'category': 'resource',
#   'type': ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_15084',
#   'question': 'When was Carl Spitteler nominated for the Nobel Prize in Literature?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_4760',
#   'question': 'WhIch is medical specialty of genetic association of FUT2 ?',
#   'category': 'resource',
#   'type': ['dbo:MedicalSpecialty']},
#  {'id': 'dbpedia_3519',
#   'question': "Did {Bible} {has edition} of {Wycliffe's Bible} and {LDS edition of the Bible} ?",
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_18430',
#   'question': 'Name the profession of Oamr D Conger for which Jack Ryan was also nominated ?',
#   'category': 'resource',
#   'type': ['dbo:Legislature', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_6993',
#   'question': 'What is music genre of comes before  I mine øjne ?',
#   'category': 'resource',
#   'type': ['dbo:MusicGenre', 'dbo:Genre', 'dbo:TopicalConcept']},
#  {'id': 'dbpedia_14516',
#   'question': 'What is  in the satellite bus of X Window System ?',
#   'category': 'resource',
#   'type': ['dbo:Software', 'dbo:Work']},
#  {'id': 'dbpedia_8054',
#   'question': 'Which is the absolute magnitude for Triton?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_19117',
#   'question': 'Which body governs over the place made by the chumash people?',
#   'category': 'resource',
#   'type': ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_22787',
#   'question': 'What is the religion of the ones in the Kampuchean Union of Salvation?',
#   'category': 'resource',
#   'type': ['dbo:Country']},
#  {'id': 'dbpedia_20306',
#   'question': 'What is the draft team of the Antoine Bibeau and also has player named Nathan Dempsey ?',
#   'category': 'resource',
#   'type': ['dbo:HockeyTeam',
#    'dbo:SportsTeam',
#    'dbo:Organisation',
#    'dbo:Agent']},
#  {'id': 'dbpedia_12859',
#   'question': 'Who is the actor who split from Oval Dreams?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_8122',
#   'question': 'What is the international parliament led by the President of the United Nations General Assembly that contains the word "assembly" in its name ?',
#   'category': 'resource',
#   'type': ['dbo:Parliament', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_2457',
#   'question': "Which is the organization that has it's headquarters located in Cleveland?",
#   'category': 'resource',
#   'type': ['dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_14045',
#   'question': 'What urban city starts with "v"?',
#   'category': 'resource',
#   'type': ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_18296',
#   'question': 'List things developed by Autoconf ?',
#   'category': 'resource',
#   'type': ['dbo:Software', 'dbo:Work']},
#  {'id': 'dbpedia_14542',
#   'question': 'Which is the spin quantum number for boson?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_290',
#   'question': 'Was Hugh_Grant relative Rick Cosnett?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_12959',
#   'question': 'Name a videogame developped by CPU that contains the word "pong" in its name',
#   'category': 'resource',
#   'type': ['dbo:VideoGame', 'dbo:Software', 'dbo:Work']},
#  {'id': 'dbpedia_10661',
#   'question': 'Is it true that the maximum gradient of the Bavarian Forest Railway equals to 12.5?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_20065',
#   'question': 'How many different genres of games can I find which are compatible with the Commodore 64?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_14915',
#   'question': "The album after The Jazz Giants '56 featured what musician?",
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_20776',
#   'question': 'Is Gaza Strip the result of Operation Autumn Clouds?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_19704',
#   'question': 'Where does the Jerusalem Institute of Justice render their services?',
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_14328',
#   'question': 'Who is the spouse of LeAnn Rimes when she was married in California?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_8615',
#   'question': 'Does cobalt-70 has a half-life that is more than 0.4?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_1999',
#   'question': 'Which is the rigid airship named after Paul von Hindenburg?',
#   'category': 'resource',
#   'type': ['dbo:Aircraft', 'dbo:MeanOfTransportation']},
#  {'id': 'dbpedia_19364',
#   'question': 'Who is the author of Heroman is also the author of Karakuri Dji Ultimo ?',
#   'category': 'resource',
#   'type': ['dbo:ComicsCreator', 'dbo:Artist', 'dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_8664',
#   'question': 'What is the synonym of taxon for angiosperms?',
#   'category': 'resource',
#   'type': ['dbo:Taxon', 'dbo:TopicalConcept']},
#  {'id': 'dbpedia_22194',
#   'question': 'What currencies are used in the country whose capital is Podgorica?',
#   'category': 'resource',
#   'type': ['dbo:Currency']},
#  {'id': 'dbpedia_23548',
#   'question': 'Give me the currency of China.',
#   'category': 'resource',
#   'type': ['dbo:Currency']},
#  {'id': 'dbpedia_22137',
#   'question': 'List all the doctoral student of the scientist who has advised john Bowlby ?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_20711',
#   'question': 'Which sitcom is broadcasted by FOX and presented by Brian Dunkleman?',
#   'category': 'resource',
#   'type': ['dbo:TelevisionShow', 'dbo:Work']},
#  {'id': 'dbpedia_10716',
#   'question': 'Mauricio Macri is the head of government for what sovereign state?',
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_13812',
#   'question': 'How much did Colin Meads score when playing for which team?',
#   'category': 'resource',
#   'type': ['dbo:SportsTeam', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_12820',
#   'question': 'Who is the mentor of Strabo, who has the profession as a philosopher?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_16155',
#   'question': "What is the publication date for Immanuel Kant's most notable work, Critique of Practical Reason?",
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_5338',
#   'question': "Give me a mobile operating system, that starts with an alphabet 'w'.",
#   'category': 'resource',
#   'type': ['dbo:Software', 'dbo:Work']},
#  {'id': 'dbpedia_22226',
#   'question': 'What river is it whose source is Dowra?',
#   'category': 'resource',
#   'type': ['dbo:River',
#    'dbo:Stream',
#    'dbo:BodyOfWater',
#    'dbo:NaturalPlace',
#    'dbo:Place']},
#  {'id': 'dbpedia_13550',
#   'question': 'What is the OpenCororates ID for Trondheim?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_13472',
#   'question': 'What was the profession of the discoverer of the Analytical Engine?',
#   'category': 'resource',
#   'type': ['dbo:AcademicSubject', 'dbo:TopicalConcept']},
#  {'id': 'dbpedia_2934',
#   'question': 'What is he company ID for Kenji Mizoguchi?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_10192',
#   'question': "Was Idi Amin in the British Armed Forces and Uganda People's Defence Force?",
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_23390',
#   'question': 'Who developed Slack?',
#   'category': 'resource',
#   'type': ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_21821',
#   'question': 'Name the company founded by Jim Harris located in Harris County, Texas ?',
#   'category': 'resource',
#   'type': ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_2799',
#   'question': 'Does the illiterate population of the Asanbani equal 0?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_18065',
#   'question': 'Which work of Craig van Tilbury is close to the area of The Chess Monthyl ?',
#   'category': 'resource',
#   'type': ['dbo:Game', 'dbo:Sport', 'dbo:Activity']},
#  {'id': 'dbpedia_7669',
#   'question': 'Publius Aelius Hadrianus Afer is the son of which characters in Memoirs of Hadrian?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_13896',
#   'question': 'Which is commanded by the Warsaw Pact?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_8402',
#   'question': 'What kinds of animals are displayed at the Smithsonian Institution?',
#   'category': 'resource',
#   'type': ['dbo:Taxon', 'dbo:TopicalConcept']},
#  {'id': 'dbpedia_23074',
#   'question': 'Through which countries does the Yenisei river flow?',
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_3035',
#   'question': 'What strategy game has the least players?',
#   'category': 'resource',
#   'type': ['dbo:BoardGame', 'dbo:Game', 'dbo:Activity']},
#  {'id': 'dbpedia_13370',
#   'question': 'Which award is received by Joan Fontaine for his work of Suspicion?',
#   'category': 'resource',
#   'type': ['dbo:Award']},
#  {'id': 'dbpedia_6434',
#   'question': 'Who is record producer Vento del sud married to?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_2700',
#   'question': 'Which is the eWRC-results.com racer ID for Sébastien Ogier?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_21118',
#   'question': 'How many had their debut team coached by Chip Kelly?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_16267',
#   'question': 'Was Jane the given, or middle name of Nellie Bly?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_14152',
# ...
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_4127',
#   'question': 'What country has The Star-Spangled Banner as its anthem?',
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_4002',
#   'question': 'What democratic republic country had the Watergate scandal?',
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_725',
#   'question': 'Where is the governmental capital of Ujjinakoppa?',
#   'category': 'resource',
#   'type': ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_14371',
#   'question': "What is the sister of the Johanna of Castile's child?",
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_15690',
#   'question': 'What is the human with the lowest national team caps whose instance of is human?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_10522',
#   'question': 'Which female holds the record in pole vaulting?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_3988',
#   'question': 'Is Janet Jackson, the performer, single?',
#   'category': 'resource',
#   'type': ['dbo:Single', 'dbo:MusicalWork', 'dbo:Work']},
#  {'id': 'dbpedia_13930',
#   'question': "What is Irish National Inventory of Architectural Heritage ID for King's Inns ?",
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_12118',
#   'question': "Where is {prime minister} {Emma Goldman}'s {place of activity}   ?",
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_11658',
#   'question': 'Is it true that the numeric value of Boltzmann constant is greater than 1.104518816?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_3899',
#   'question': 'Is the total produced by Tupolev ANT-1 equal to 1.2?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_15308',
#   'question': 'What type of geology of anorthite is monitored by the Vesuvius Observatory during eruptions?',
#   'category': 'resource',
#   'type': ['dbo:Mountain', 'dbo:NaturalPlace', 'dbo:Place']},
#  {'id': 'dbpedia_4393',
#   'question': 'Who was a student of Maurice Ravel?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_14799',
#   'question': 'What academic major studies Hebrew?',
#   'category': 'resource',
#   'type': ['dbo:AcademicSubject', 'dbo:TopicalConcept']},
#  {'id': 'dbpedia_11083',
#   'question': 'Who is the employer of The Guardian?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_4060',
#   'question': 'What is the capital of the is in the city  of Jauca?',
#   'category': 'resource',
#   'type': ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_14467',
#   'question': '"What is {forename} of {Walter Yeo}, which has {similar to} is {Wöltje} ?"',
#   'category': 'resource',
#   'type': ['dbo:GivenName', 'dbo:Name']},
#  {'id': 'dbpedia_18405',
#   'question': 'Who is the successor of McDonnell Douglas ?',
#   'category': 'resource',
#   'type': ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_11014',
#   'question': 'which radio program starts with o',
#   'category': 'resource',
#   'type': ['dbo:RadioProgram', 'dbo:Work']},
#  {'id': 'dbpedia_7146',
#   'question': 'What was the name of the International Master chess player with the lowest rating?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_10385',
#   'question': 'What is area code of the admin HQ of the New York Stock Exchange ?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_21133',
#   'question': 'List all the members of the organization whose one of the members is Bangladesh ?',
#   'category': 'resource',
#   'type': ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_2747',
#   'question': 'Who is the architect of the Chapultepec Castleon?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_9936',
#   'question': 'grant wood delarge id?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_3980',
#   'question': 'When did Lombardy become known as the Kingdom of Italy?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_20435',
#   'question': 'Which shows are voiced be US citizens?',
#   'category': 'resource',
#   'type': ['dbo:TelevisionShow', 'dbo:Work']},
#  {'id': 'dbpedia_11798',
#   'question': 'What is the ICAO airport code for the Shanghai Pudong International Airport?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_12353',
#   'question': 'When did Claire Trevor and Milton H. Bren get married?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_467',
#   'question': 'Where in the Soviet Union did Andrei Bely die?',
#   'category': 'resource',
#   'type': ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_7274',
#   'question': 'Who is {sister} of {musical artist} of {That Song in My Head} ?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_7106',
#   'question': 'What is the alumna of Jenny Holzer, who is in the category for employees of the organization Ohio University faculty?',
#   'category': 'resource',
#   'type': ['dbo:University',
#    'dbo:EducationalInstitution',
#    'dbo:Organisation',
#    'dbo:Agent']},
#  {'id': 'dbpedia_16325',
#   'question': 'Walt Disney is apart of what production company?',
#   'category': 'resource',
#   'type': ['dbo:Film', 'dbo:Work']},
#  {'id': 'dbpedia_17043',
#   'question': 'Which bank issued the Russian ruble?',
#   'category': 'resource',
#   'type': ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_15111',
#   'question': 'What is the name of the book classified in encyclopedia?',
#   'category': 'resource',
#   'type': ['dbo:Book', 'dbo:WrittenWork', 'dbo:Work']},
#  {'id': 'dbpedia_19182',
#   'question': 'How many players are in the San Francisco Giants?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_19886',
#   'question': 'Is coffee a main ingredient of Hopje?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_12873',
#   'question': 'What are the Hindu temple which start with the letter t',
#   'category': 'resource',
#   'type': ['dbo:Village',
#    'dbo:Settlement',
#    'dbo:PopulatedPlace',
#    'dbo:Place']},
#  {'id': 'dbpedia_4143',
#   'question': 'What does tobramycin treat?',
#   'category': 'resource',
#   'type': ['dbo:ChemicalCompound', 'dbo:ChemicalSubstance']},
#  {'id': 'dbpedia_1217',
#   'question': 'IS THE TIME IN SPACE OF CATHERINE COLEMAN EQUALS TO 207552.O',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_8858',
#   'question': 'What is Canmore ID for Forth Bridge ?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_10605',
#   'question': 'Who is the husband of the author of the book Goldilocks?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_20467',
#   'question': 'Does Stanley Cavell study Shakespeare?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_17975',
#   'question': 'What science is the study of addiction?',
#   'category': 'resource',
#   'type': ['dbo:Disease']},
#  {'id': 'dbpedia_2592',
#   'question': 'Which is language of platforms of Army of Darkness: Defense ?',
#   'category': 'resource',
#   'type': ['dbo:ProgrammingLanguage', 'dbo:Language']},
#  {'id': 'dbpedia_7258',
#   'question': 'Which sport tour has the highest number of losses?',
#   'category': 'resource',
#   'type': ['dbo:Activity']},
#  {'id': 'dbpedia_21267',
#   'question': 'Rostock and Oulu is the shore cities on which sea ?',
#   'category': 'resource',
#   'type': ['dbo:Lake',
#    'dbo:Sea',
#    'dbo:BodyOfWater',
#    'dbo:NaturalPlace',
#    'dbo:Place']},
#  {'id': 'dbpedia_22110',
#   'question': 'Which license provider of MSX basic is also the designer of Language Integrated Query ?',
#   'category': 'resource',
#   'type': ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_10072',
#   'question': 'Was Euro country Finland  and Latvia?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_3294',
#   'question': 'WHat is the project involving nuclear weapons that contains the word "manhattan" in its name ?',
#   'category': 'resource',
#   'type': ['dbo:Activity']},
#  {'id': 'dbpedia_8458',
#   'question': 'Which is the programming language of Bitcoin?',
#   'category': 'resource',
#   'type': ['dbo:ProgrammingLanguage', 'dbo:Language']},
#  {'id': 'dbpedia_15076',
#   'question': 'In which year Steve Jobs finished his education from the Reed College?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_2330',
#   'question': 'Who are the sons starring in H. Con-172',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_1420',
#   'question': 'Where does the sonata come from?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_16288',
#   'question': 'Which is the ESPN.com NFL player ID for Kurt Warner?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_7358',
#   'question': 'Was the Google search creator Larry Page?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_9957',
#   'question': 'Milan is located in what administrative territory its twinned administrative body?',
#   'category': 'resource',
#   'type': ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_4751',
#   'question': 'Which is the Compagnon de la Libération ID for Winston Churchill?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_3454',
#   'question': 'What is the flash point of malathion whose criterion used is lower bound?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_15303',
#   'question': 'How many manufacturers are for Concorde?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_4941',
#   'question': 'Heinrich Schütz holds the seat for which county?',
#   'category': 'resource',
#   'type': ['dbo:State', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_4973',
#   'question': 'Which tributary of the Neman River flows to the right?',
#   'category': 'resource',
#   'type': ['dbo:River',
#    'dbo:Stream',
#    'dbo:BodyOfWater',
#    'dbo:NaturalPlace',
#    'dbo:Place']},
#  {'id': 'dbpedia_15209',
#   'question': "Which musician's sequel is Amos Moses?",
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_5372',
#   'question': 'Which ballet was composed by Pyotr Ilyich Tchaikovsky?',
#   'category': 'resource',
#   'type': ['dbo:MusicalWork', 'dbo:Work']},
#  {'id': 'dbpedia_14977',
#   'question': 'Which is the home world for Superman?',
#   'category': 'resource',
#   'type': ['dbo:Work']},
#  {'id': 'dbpedia_19948',
#   'question': 'Is Maldives a member ofof South Asia Subregional Economic Cooperation?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_23137',
#   'question': 'When did princess Diana die?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_4704',
#   'question': 'Name a alternative version of Gospel of Matthew',
#   'category': 'resource',
#   'type': ['dbo:Media']},
#  {'id': 'dbpedia_16000',
#   'question': 'when did erfurt and kalisz begin their administrative responsibilities?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_6516',
#   'question': 'Which film is set in the Marvel Cinematic Universe?',
#   'category': 'resource',
#   'type': ['dbo:Film', 'dbo:Work']},
#  {'id': 'dbpedia_5010',
#   'question': 'What characters are part of the series called A Fish Called Selma?',
#   'category': 'resource',
#   'type': ['dbo:Work']},
#  {'id': 'dbpedia_14439',
#   'question': 'Mention the spaceflight crew participant for accompanying Yuri Gagarin',
#   'category': 'resource',
#   'type': ['dbo:Spacecraft', 'dbo:MeanOfTransportation']},
#  {'id': 'dbpedia_23553',
#   'question': 'Give me all Swedish oceanographers.',
#   'category': 'resource',
#   'type': ['dbo:Scientist', 'dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_13437',
#   'question': 'Mention the Vidhan Sabha body of Karnataka.',
#   'category': 'resource',
#   'type': ['dbo:Organisation', 'dbo:Agent']},
#  {'id': 'dbpedia_8902',
#   'question': 'From the work Neighbours, what was Margot Robbie nominated for?',
#   'category': 'resource',
#   'type': ['dbo:Award']},
#  {'id': 'dbpedia_15610',
#   'question': 'When is the endtime of trend of Miserere?',
#   'category': 'literal',
#   'type': ['date']},
#  {'id': 'dbpedia_6818',
#   'question': 'What is a cause of botulism?',
#   'category': 'resource',
#   'type': ['dbo:Taxon', 'dbo:TopicalConcept']},
#  {'id': 'dbpedia_22391',
#   'question': 'Name the co-founder of the record labels which have one of the founder as Chris DuBois ?',
#   'category': 'resource',
#   'type': ['dbo:MusicalArtist', 'dbo:Artist', 'dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_892',
#   'question': 'Who composed The Carnival of the Animals?',
#   'category': 'resource',
#   'type': ['dbo:Profession', 'dbo:PersonFunction']},
#  {'id': 'dbpedia_11938',
#   'question': 'Who wrote The Jungle Book ?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_6983',
#   'question': 'What opponent competed against Kerri Walsh Jennings?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_11085',
#   'question': 'Was Jordan Peterson an employer of Massachusetts Institute of Technology and University of Toronto?',
#   'category': 'boolean',
#   'type': ['boolean']},
#  {'id': 'dbpedia_5928',
#   'question': 'Who is the  {legal case} for {defendant} of {Bill Cosby}',
#   'category': 'resource',
#   'type': ['dbo:LegalCase', 'dbo:Case', 'dbo:UnitOfWork']},
#  {'id': 'dbpedia_989',
#   'question': 'what is the human population from the originates of Mind?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_16699',
#   'question': 'What is a license made out of?',
#   'category': 'resource',
#   'type': ['dbo:Software', 'dbo:Work']},
#  {'id': 'dbpedia_12407',
#   'question': 'Which is the EC ID of copper?',
#   'category': 'literal',
#   'type': ['string']},
#  {'id': 'dbpedia_19969',
#   'question': 'Which spanish novel was published by Francisco de Robles?',
#   'category': 'resource',
#   'type': ['dbo:Book', 'dbo:WrittenWork', 'dbo:Work']},
#  {'id': 'dbpedia_11319',
#   'question': 'Who is the {protein} for {physically interacts with} of {fentanyl}',
#   'category': 'resource',
#   'type': ['dbo:Protein', 'dbo:Biomolecule']},
#  {'id': 'dbpedia_6027',
#   'question': 'What is the salinity of the Baltic Sea?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_3637',
#   'question': "What is the tributary of Mindanao's body of water?",
#   'category': 'resource',
#   'type': ['dbo:River',
#    'dbo:Stream',
#    'dbo:BodyOfWater',
#    'dbo:NaturalPlace',
#    'dbo:Place']},
#  {'id': 'dbpedia_10157',
#   'question': 'Who is the person that was doctoral adviser of Paul Krugman?',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_22609',
#   'question': 'What are some team members of the team based in Camp Nou?',
#   'category': 'resource',
#   'type': ['dbo:SoccerPlayer', 'dbo:Athlete', 'dbo:Person', 'dbo:Agent']},
#  {'id': 'dbpedia_649',
#   'question': 'In what theatrical field was Allen Ginsberg employed?',
#   'category': 'resource',
#   'type': ['dbo:Activity']},
#  {'id': 'dbpedia_10342',
#   'question': 'Where did William Henry Harrison die and where was he buried?',
#   'category': 'resource',
#   'type': ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']},
#  {'id': 'dbpedia_12084',
#   'question': 'What were the characteristics of the historical inhabitants of Macau?',
#   'category': 'literal',
#   'type': ['number']},
#  {'id': 'dbpedia_5200',
#   'question': 'Who designed the Metropolitan Railway A Class?',
#   'category': 'resource',
#   'type': ['dbo:Bridge',
#    'dbo:RouteOfTransportation',
#    'dbo:Infrastructure',
#    'dbo:ArchitecturalStructure',
#    'dbo:Place']},
#  ...]

# %%
import copy
at_db_test_copy = copy.deepcopy(at_db_test)

owl = '<http://www.w3.org/2002/07/owl#>'
rdfs = '<http://www.w3.org/2000/01/rdf-schema#>'
dbo = '<http://dbpedia.org/ontology/>'

from rdflib import Graph
from SPARQLWrapper import SPARQLWrapper, JSON, N3
from pprint import pprint

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
for idx, entry in enumerate(at_db_test_copy):
    if entry['category'] == 'resource':
        type_list = []
        type_list.append(entry['type'][0])
        
        query = 'SELECT DISTINCT ?parentClass WHERE {'+type_list[0]+' rdfs:subClassOf* ?parentClass. FILTER(?parentClass != ' + type_list[0] + '&& CONTAINS(STR(?parentClass), "dbpedia")) }'

        sparql = SPARQLWrapper('https://dbpedia.org/sparql')

        for retries in range(3):
            try:
                sparql.setQuery(query)
                sparql.setReturnFormat(JSON)
                qres = sparql.query().convert()

                for x in qres['results']['bindings']:
                    type_list.append('dbo:'+x['parentClass']['value'].split('/')[-1])   

                print(entry['type'], type_list)
                entry['type'] = type_list
                if len(qres) != 0:
                    break
                
            except Exception as E:
                print('trying again ...')
# Out:
# ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Mountain', 'dbo:NaturalPlace', 'dbo:Place'] ['dbo:Mountain', 'dbo:NaturalPlace', 'dbo:Place']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Disease'] ['dbo:Disease']
# ['dbo:SportsTeam', 'dbo:Organisation', 'dbo:Agent'] ['dbo:SportsTeam', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:PoliticalParty'] ['dbo:PoliticalParty', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:MusicGenre', 'dbo:Genre', 'dbo:TopicalConcept'] ['dbo:MusicGenre', 'dbo:Genre', 'dbo:TopicalConcept']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Asteroid', 'dbo:CelestialBody', 'dbo:Place'] ['dbo:Asteroid', 'dbo:CelestialBody', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Software', 'dbo:Work'] ['dbo:Software', 'dbo:Work']
# ['dbo:MusicalArtist', 'dbo:Person', 'dbo:Agent'] ['dbo:MusicalArtist', 'dbo:Artist', 'dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Disease'] ['dbo:Disease']
# ['dbo:Profession', 'dbo:PersonFunction'] ['dbo:Profession', 'dbo:PersonFunction']
# ['dbo:AmericanFootballTeam', 'dbo:SoccerClub', 'dbo:SportsTeam', 'dbo:Organisation', 'dbo:Agent'] ['dbo:AmericanFootballTeam', 'dbo:SportsTeam', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Film', 'dbo:TelevisionShow', 'dbo:Work'] ['dbo:Film', 'dbo:Work']
# ['dbo:Profession', 'dbo:PersonFunction'] ['dbo:Profession', 'dbo:PersonFunction']
# ['dbo:Organisation', 'dbo:Agent'] ['dbo:Organisation', 'dbo:Agent']
# ['dbo:Organisation', 'dbo:Agent'] ['dbo:Organisation', 'dbo:Agent']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Disease'] ['dbo:Disease']
# ['dbo:GovernmentAgency', 'dbo:Organisation', 'dbo:Agent'] ['dbo:GovernmentAgency', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Magazine', 'dbo:PeriodicalLiterature', 'dbo:WrittenWork', 'dbo:Work'] ['dbo:Magazine', 'dbo:PeriodicalLiterature', 'dbo:WrittenWork', 'dbo:Work']
# ['dbo:Award'] ['dbo:Award']
# ['dbo:AcademicSubject', 'dbo:TopicalConcept'] ['dbo:AcademicSubject', 'dbo:TopicalConcept']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:River', 'dbo:Stream', 'dbo:BodyOfWater', 'dbo:NaturalPlace', 'dbo:Place'] ['dbo:River', 'dbo:Stream', 'dbo:BodyOfWater', 'dbo:NaturalPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:ProgrammingLanguage', 'dbo:Language'] ['dbo:ProgrammingLanguage', 'dbo:Language']
# ['dbo:Election', 'dbo:SocietalEvent', 'dbo:Event'] ['dbo:Election', 'dbo:SocietalEvent', 'dbo:Event']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:AnatomicalStructure'] ['dbo:AnatomicalStructure']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Film', 'dbo:Work'] ['dbo:Film', 'dbo:Work']
# ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Brain', 'dbo:AnatomicalStructure'] ['dbo:Brain', 'dbo:AnatomicalStructure']
# ['dbo:University', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent'] ['dbo:University', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:BaseballTeam', 'dbo:SportsTeam', 'dbo:Organisation', 'dbo:Agent'] ['dbo:BaseballTeam', 'dbo:SportsTeam', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Archipelago', 'dbo:NaturalPlace', 'dbo:Place'] ['dbo:Archipelago', 'dbo:NaturalPlace', 'dbo:Place']
# ['dbo:Non-ProfitOrganisation', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Non-ProfitOrganisation', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Non-ProfitOrganisation', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Non-ProfitOrganisation', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:FictionalCharacter', 'dbo:Person', 'dbo:Agent'] ['dbo:FictionalCharacter', 'dbo:Agent']
# ['dbo:Media'] ['dbo:Media']
# ['dbo:Organisation', 'dbo:Agent'] ['dbo:Organisation', 'dbo:Agent']
# ['dbo:Album', 'dbo:MusicalWork', 'dbo:Work'] ['dbo:Album', 'dbo:MusicalWork', 'dbo:Work']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:River', 'dbo:Stream', 'dbo:BodyOfWater', 'dbo:NaturalPlace', 'dbo:Place'] ['dbo:River', 'dbo:Stream', 'dbo:BodyOfWater', 'dbo:NaturalPlace', 'dbo:Place']
# ['dbo:Ship', 'dbo:MeanOfTransportation'] ['dbo:Ship', 'dbo:MeanOfTransportation']
# trying again ...
# ['dbo:HorseRace', 'dbo:Race', 'dbo:SportsEvent', 'dbo:SocietalEvent', 'dbo:Event'] ['dbo:HorseRace', 'dbo:Race', 'dbo:SportsEvent', 'dbo:SocietalEvent', 'dbo:Event']
# trying again ...
# ['dbo:Disease'] ['dbo:Disease']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Organisation', 'dbo:Agent'] ['dbo:Organisation', 'dbo:Agent']
# ['dbo:TelevisionShow', 'dbo:Work'] ['dbo:TelevisionShow', 'dbo:Work']
# ['dbo:ChemicalCompound', 'dbo:ChemicalSubstance'] ['dbo:ChemicalCompound', 'dbo:ChemicalSubstance']
# trying again ...
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Disease'] ['dbo:Disease']
# ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Film', 'dbo:Work'] ['dbo:Film', 'dbo:Work']
# ['dbo:ChemicalCompound', 'dbo:ChemicalSubstance'] ['dbo:ChemicalCompound', 'dbo:ChemicalSubstance']
# ['dbo:Country', 'dbo:City', 'dbo:State', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:MountainRange', 'dbo:NaturalPlace', 'dbo:Place'] ['dbo:MountainRange', 'dbo:NaturalPlace', 'dbo:Place']
# ['dbo:Book', 'dbo:WrittenWork', 'dbo:Work'] ['dbo:Book', 'dbo:WrittenWork', 'dbo:Work']
# ['dbo:SoccerManager', 'dbo:SportsManager', 'dbo:SoccerPlayer', 'dbo:Person', 'dbo:Agent'] ['dbo:SoccerManager', 'dbo:SportsManager', 'dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Disease'] ['dbo:Disease']
# ['dbo:TelevisionShow', 'dbo:Work'] ['dbo:TelevisionShow', 'dbo:Work']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:ProgrammingLanguage', 'dbo:Language'] ['dbo:ProgrammingLanguage', 'dbo:Language']
# ['dbo:PoliticalParty'] ['dbo:PoliticalParty', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Airline', 'dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Airline', 'dbo:PublicTransitSystem', 'dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:BaseballTeam', 'dbo:SportsTeam', 'dbo:Organisation', 'dbo:Agent'] ['dbo:BaseballTeam', 'dbo:SportsTeam', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Gene', 'dbo:Biomolecule'] ['dbo:Gene', 'dbo:Biomolecule']
# ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Award'] ['dbo:Award']
# ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:TelevisionShow', 'dbo:Work'] ['dbo:TelevisionShow', 'dbo:Work']
# ['dbo:TelevisionShow', 'dbo:Work'] ['dbo:TelevisionShow', 'dbo:Work']
# ['dbo:Taxon', 'dbo:TopicalConcept'] ['dbo:Taxon', 'dbo:TopicalConcept']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Activity'] ['dbo:Activity']
# ['dbo:SpaceStation', 'dbo:MeanOfTransportation'] ['dbo:SpaceStation', 'dbo:MeanOfTransportation']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Book', 'dbo:WrittenWork', 'dbo:Work'] ['dbo:Book', 'dbo:WrittenWork', 'dbo:Work']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Newspaper', 'dbo:PeriodicalLiterature', 'dbo:WrittenWork', 'dbo:Work'] ['dbo:Newspaper', 'dbo:PeriodicalLiterature', 'dbo:WrittenWork', 'dbo:Work']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Legislature', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Legislature', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Film', 'dbo:Work'] ['dbo:Film', 'dbo:Work']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Taxon', 'dbo:TopicalConcept'] ['dbo:Taxon', 'dbo:TopicalConcept']
# trying again ...
# trying again ...
# ['dbo:MilitaryUnit', 'dbo:Organisation', 'dbo:Agent'] ['dbo:MilitaryUnit', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Software', 'dbo:Work'] ['dbo:Software', 'dbo:Work']
# ['dbo:Work'] ['dbo:Work']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Organisation', 'dbo:Agent'] ['dbo:Organisation', 'dbo:Agent']
# trying again ...
# trying again ...
# ['dbo:TelevisionShow', 'dbo:Film', 'dbo:Work'] ['dbo:TelevisionShow', 'dbo:Work']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# trying again ...
# trying again ...
# ['dbo:Country'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Name'] ['dbo:Name']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Lake', 'dbo:Sea', 'dbo:BodyOfWater', 'dbo:NaturalPlace', 'dbo:Place'] ['dbo:Lake', 'dbo:BodyOfWater', 'dbo:NaturalPlace', 'dbo:Place']
# ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:PoliticalParty'] ['dbo:PoliticalParty', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:MedicalSpecialty'] ['dbo:MedicalSpecialty']
# ['dbo:Legislature', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Legislature', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:MusicGenre', 'dbo:Genre', 'dbo:TopicalConcept'] ['dbo:MusicGenre', 'dbo:Genre', 'dbo:TopicalConcept']
# ['dbo:Software', 'dbo:Work'] ['dbo:Software', 'dbo:Work']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Country'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:HockeyTeam', 'dbo:SportsTeam', 'dbo:Organisation', 'dbo:Agent'] ['dbo:HockeyTeam', 'dbo:SportsTeam', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Parliament', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Parliament', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Organisation', 'dbo:Agent'] ['dbo:Organisation', 'dbo:Agent']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Software', 'dbo:Work'] ['dbo:Software', 'dbo:Work']
# ['dbo:VideoGame', 'dbo:Software', 'dbo:Work'] ['dbo:VideoGame', 'dbo:Software', 'dbo:Work']
# trying again ...
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# trying again ...
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Aircraft', 'dbo:MeanOfTransportation'] ['dbo:Aircraft', 'dbo:MeanOfTransportation']
# ['dbo:ComicsCreator', 'dbo:Artist', 'dbo:Person', 'dbo:Agent'] ['dbo:ComicsCreator', 'dbo:Artist', 'dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Taxon', 'dbo:TopicalConcept'] ['dbo:Taxon', 'dbo:TopicalConcept']
# trying again ...
# ['dbo:Currency'] ['dbo:Currency']
# ['dbo:Currency'] ['dbo:Currency']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:TelevisionShow', 'dbo:Work'] ['dbo:TelevisionShow', 'dbo:Work']
# trying again ...
# ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:SportsTeam', 'dbo:Organisation', 'dbo:Agent'] ['dbo:SportsTeam', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Software', 'dbo:Work'] ['dbo:Software', 'dbo:Work']
# ['dbo:River', 'dbo:Stream', 'dbo:BodyOfWater', 'dbo:NaturalPlace', 'dbo:Place'] ['dbo:River', 'dbo:Stream', 'dbo:BodyOfWater', 'dbo:NaturalPlace', 'dbo:Place']
# ['dbo:AcademicSubject', 'dbo:TopicalConcept'] ['dbo:AcademicSubject', 'dbo:TopicalConcept']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Game', 'dbo:Sport', 'dbo:Activity'] ['dbo:Game', 'dbo:Activity']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Taxon', 'dbo:TopicalConcept'] ['dbo:Taxon', 'dbo:TopicalConcept']
# ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:BoardGame', 'dbo:Game', 'dbo:Activity'] ['dbo:BoardGame', 'dbo:Game', 'dbo:Activity']
# ['dbo:Award'] ['dbo:Award']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:MusicGenre', 'dbo:Genre', 'dbo:TopicalConcept'] ['dbo:MusicGenre', 'dbo:Genre', 'dbo:TopicalConcept']
# ['dbo:ComicsCreator', 'dbo:Artist', 'dbo:Person', 'dbo:Agent'] ['dbo:ComicsCreator', 'dbo:Artist', 'dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Writer', 'dbo:Person', 'dbo:Agent'] ['dbo:Writer', 'dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Artery', 'dbo:AnatomicalStructure'] ['dbo:Artery', 'dbo:AnatomicalStructure']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# trying again ...
# ['dbo:ChemicalCompound', 'dbo:ChemicalSubstance'] ['dbo:ChemicalCompound', 'dbo:ChemicalSubstance']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# trying again ...
# trying again ...
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Mountain', 'dbo:NaturalPlace', 'dbo:Place'] ['dbo:Mountain', 'dbo:NaturalPlace', 'dbo:Place']
# trying again ...
# ['dbo:OfficeHolder', 'dbo:President', 'dbo:Politician', 'dbo:Person', 'dbo:Agent'] ['dbo:OfficeHolder', 'dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Organisation', 'dbo:Agent'] ['dbo:Organisation', 'dbo:Agent']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:TelevisionShow', 'dbo:Work'] ['dbo:TelevisionShow', 'dbo:Work']
# trying again ...
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Media'] ['dbo:Media']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Single', 'dbo:MusicalWork', 'dbo:Work'] ['dbo:Single', 'dbo:MusicalWork', 'dbo:Work']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Dam', 'dbo:Infrastructure', 'dbo:ArchitecturalStructure', 'dbo:Place'] ['dbo:Dam', 'dbo:Infrastructure', 'dbo:ArchitecturalStructure']
# ['dbo:OfficeHolder', 'dbo:Person', 'dbo:Agent'] ['dbo:OfficeHolder', 'dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:OfficeHolder', 'dbo:Person', 'dbo:Agent'] ['dbo:OfficeHolder', 'dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:FilmFestival', 'dbo:SocietalEvent', 'dbo:Event'] ['dbo:FilmFestival', 'dbo:SocietalEvent', 'dbo:Event']
# ['dbo:Work'] ['dbo:Work']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:TennisPlayer', 'dbo:Athlete', 'dbo:Person', 'dbo:Agent'] ['dbo:TennisPlayer', 'dbo:Athlete', 'dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# trying again ...
# ['dbo:Book', 'dbo:WrittenWork', 'dbo:Work'] ['dbo:Book', 'dbo:WrittenWork', 'dbo:Work']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Taxon', 'dbo:TopicalConcept'] ['dbo:Taxon', 'dbo:TopicalConcept']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Writer', 'dbo:Person', 'dbo:Agent'] ['dbo:Writer', 'dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Band', 'dbo:Group', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Band', 'dbo:Group', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Museum', 'dbo:Building', 'dbo:ArchitecturalStructure', 'dbo:Place'] ['dbo:Museum', 'dbo:Building', 'dbo:ArchitecturalStructure']
# ['dbo:Award'] ['dbo:Award']
# trying again ...
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Organisation', 'dbo:Agent'] ['dbo:Organisation', 'dbo:Agent']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:University', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent'] ['dbo:University', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Taxon', 'dbo:TopicalConcept'] ['dbo:Taxon', 'dbo:TopicalConcept']
# trying again ...
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# trying again ...
# ['dbo:River', 'dbo:Stream', 'dbo:BodyOfWater', 'dbo:NaturalPlace', 'dbo:Place'] ['dbo:River', 'dbo:Stream', 'dbo:BodyOfWater', 'dbo:NaturalPlace', 'dbo:Place']
# ['dbo:Sport', 'dbo:Activity'] ['dbo:Sport', 'dbo:Activity']
# ['dbo:Bridge', 'dbo:RouteOfTransportation', 'dbo:Infrastructure', 'dbo:ArchitecturalStructure', 'dbo:Place'] ['dbo:Bridge', 'dbo:RouteOfTransportation', 'dbo:Infrastructure', 'dbo:ArchitecturalStructure']
# trying again ...
# ['dbo:Award'] ['dbo:Award']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# trying again ...
# ['dbo:University', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent'] ['dbo:University', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:MobilePhone', 'dbo:Device'] ['dbo:MobilePhone', 'dbo:Device']
# ['dbo:InformationAppliance', 'dbo:Device'] ['dbo:InformationAppliance', 'dbo:Device']
# ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Bridge', 'dbo:RouteOfTransportation', 'dbo:Infrastructure', 'dbo:ArchitecturalStructure', 'dbo:Place'] ['dbo:Bridge', 'dbo:RouteOfTransportation', 'dbo:Infrastructure', 'dbo:ArchitecturalStructure']
# ['dbo:AcademicJournal', 'dbo:PeriodicalLiterature', 'dbo:WrittenWork', 'dbo:Work'] ['dbo:AcademicJournal', 'dbo:PeriodicalLiterature', 'dbo:WrittenWork', 'dbo:Work']
# ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Film', 'dbo:Work'] ['dbo:Film', 'dbo:Work']
# ['dbo:EthnicGroup'] ['dbo:EthnicGroup']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Library', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Library', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Activity'] ['dbo:Activity']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Sport', 'dbo:Game', 'dbo:Activity'] ['dbo:Sport', 'dbo:Activity']
# ['dbo:School', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent'] ['dbo:School', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Media'] ['dbo:Media']
# trying again ...
# ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# trying again ...
# trying again ...
# ['dbo:Organisation', 'dbo:Agent'] ['dbo:Organisation', 'dbo:Agent']
# ['dbo:Book', 'dbo:WrittenWork', 'dbo:Work'] ['dbo:Book', 'dbo:WrittenWork', 'dbo:Work']
# ['dbo:University', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent'] ['dbo:University', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:University', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent'] ['dbo:University', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent']
# trying again ...
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Country', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Media'] ['dbo:Media']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Award'] ['dbo:Award']
# ['dbo:Activity'] ['dbo:Activity']
# ['dbo:PopulatedPlace', 'dbo:Place'] ['dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:River', 'dbo:Stream', 'dbo:BodyOfWater', 'dbo:NaturalPlace', 'dbo:Place'] ['dbo:River', 'dbo:Stream', 'dbo:BodyOfWater', 'dbo:NaturalPlace', 'dbo:Place']
# ['dbo:Work'] ['dbo:Work']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Church', 'dbo:ReligiousBuilding', 'dbo:Building', 'dbo:ArchitecturalStructure', 'dbo:Place'] ['dbo:Church', 'dbo:ReligiousBuilding', 'dbo:Building', 'dbo:ArchitecturalStructure']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Village', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Village', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Media'] ['dbo:Media']
# ['dbo:Country'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:SoccerPlayer', 'dbo:Athlete', 'dbo:Person', 'dbo:Agent'] ['dbo:SoccerPlayer', 'dbo:Athlete', 'dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# trying again ...
# trying again ...
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:GivenName', 'dbo:Name'] ['dbo:GivenName', 'dbo:Name']
# ['dbo:State', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:State', 'dbo:PopulatedPlace', 'dbo:Place']
# trying again ...
# trying again ...
# ['dbo:State', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:State', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:PoliticalParty'] ['dbo:PoliticalParty', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Sport', 'dbo:Activity'] ['dbo:Sport', 'dbo:Activity']
# ['dbo:AmericanFootballPlayer', 'dbo:GridironFootballPlayer', 'dbo:Athlete', 'dbo:Person', 'dbo:Agent'] ['dbo:AmericanFootballPlayer', 'dbo:GridironFootballPlayer', 'dbo:Athlete', 'dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Award'] ['dbo:Award']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Currency'] ['dbo:Currency']
# ['dbo:MedicalSpecialty'] ['dbo:MedicalSpecialty']
# ['dbo:Game', 'dbo:Sport', 'dbo:Activity'] ['dbo:Game', 'dbo:Activity']
# ['dbo:Media'] ['dbo:Media']
# ['dbo:Muscle', 'dbo:AnatomicalStructure'] ['dbo:Muscle', 'dbo:AnatomicalStructure']
# ['dbo:Constellation', 'dbo:CelestialBody', 'dbo:Place'] ['dbo:Constellation', 'dbo:CelestialBody', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:MedicalSpecialty'] ['dbo:MedicalSpecialty']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Election', 'dbo:SocietalEvent', 'dbo:Event'] ['dbo:Election', 'dbo:SocietalEvent', 'dbo:Event']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:ChemicalCompound', 'dbo:ChemicalSubstance'] ['dbo:ChemicalCompound', 'dbo:ChemicalSubstance']
# ['dbo:Gene', 'dbo:Biomolecule'] ['dbo:Gene', 'dbo:Biomolecule']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Work'] ['dbo:Work']
# ['dbo:Airport', 'dbo:Infrastructure', 'dbo:ArchitecturalStructure', 'dbo:Place'] ['dbo:Airport', 'dbo:Infrastructure', 'dbo:ArchitecturalStructure']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Organisation', 'dbo:Agent'] ['dbo:Organisation', 'dbo:Agent']
# ['dbo:Book', 'dbo:WrittenWork', 'dbo:Work'] ['dbo:Book', 'dbo:WrittenWork', 'dbo:Work']
# ['dbo:RecordLabel', 'dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:RecordLabel', 'dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Deity', 'dbo:Agent'] ['dbo:Deity', 'dbo:Agent']
# ['dbo:Film', 'dbo:Work'] ['dbo:Film', 'dbo:Work']
# ['dbo:HistoricalRegion', 'dbo:Region', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:HistoricalRegion', 'dbo:Region', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Mammal', 'dbo:Animal', 'dbo:Plant', 'dbo:Eukaryote', 'dbo:Species'] ['dbo:Mammal', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:HistoricalPeriod', 'dbo:TimePeriod'] ['dbo:HistoricalPeriod', 'dbo:TimePeriod']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:City', 'dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Legislature', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Legislature', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:TelevisionShow', 'dbo:Work'] ['dbo:TelevisionShow', 'dbo:Work']
# trying again ...
# ['dbo:Film', 'dbo:Work'] ['dbo:Film', 'dbo:Work']
# ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Organisation', 'dbo:Agent'] ['dbo:Organisation', 'dbo:Agent']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Organisation', 'dbo:Agent'] ['dbo:Organisation', 'dbo:Agent']
# ['dbo:Island', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Island', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:ChemicalCompound', 'dbo:ChemicalSubstance'] ['dbo:ChemicalCompound', 'dbo:ChemicalSubstance']
# ['dbo:University', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent'] ['dbo:University', 'dbo:EducationalInstitution', 'dbo:Organisation', 'dbo:Agent']
# ['dbo:Person', 'dbo:Agent'] ['dbo:Person', 'dbo:Animal', 'dbo:Eukaryote', 'dbo:Species']
# ['dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Settlement', 'dbo:PopulatedPlace', 'dbo:Place']
# ['dbo:Company', 'dbo:Organisation', 'dbo:Agent'] ['dbo:Company', 'dbo:Organisation', 'dbo:Agent']
# trying again ...
# ['dbo:Country', 'dbo:State', 'dbo:PopulatedPlace', 'dbo:Place'] ['dbo:Country', 'dbo:PopulatedPlace', 'dbo:Place']

# %%
at_db_test_copy

# %%
for entry in at_db_test_copy:
    if entry['category'] == 'resource':
        type_list = []
        type_list.append(entry['type'][0])
        
        print(type_list[0])

        
        query = 'SELECT DISTINCT ?parentClass' +
            'WHERE { ' + type_list[0] + 'rdfs:subClassOf* ?parentClass .'' + 
            'FILTER(?parentClass != ' + type_list[0] + '&& CONTAINS(STR(?parentClass), "dbpedia")) }'
        
        print(query)
        sparql.setQuery('''
            SELECT DISTINCT ?parentClass 
            WHERE { dbo:type_list[0] rdfs:subClassOf* ?parentClass .
            FILTER(?parentClass != dbo:type_list[0] && CONTAINS(STR(?parentClass), "dbpedia"))
            }
        ''')
        sparql.setReturnFormat(JSON)
        qres = sparql.query().convert()
        for x in qres['results']['bindings']:
            type_list.append(x['parentClass']['value'].split('/')[-1])   
        
        print(type_list)

# %%
at_db_test

# %%
word = []
for x in range(len(at_db_train)):
    q, t = at_db_train[x]['question'], at_db_train[x]['category']
    if t == 'literal':
        print(q)
        word.append(q.split(' ')[0])
    else:
        word.append('others')

# %%
uq_word, qid, ct = np.unique(np.array(word), return_counts=True, return_index=True)

# %%
uq_word

# %%
ct

# %%
print([uq_word[x] for x in range(len(uq_word)) if ct[x]>100])

# %%
print([uq_word[x] for x in range(len(uq_word)) if ct[x]>5])

# %%
word = []
for x in range(len(at_db_train)):
    q, t = at_db_train[x]['question'], at_db_train[x]['category']
    if t == 'boolean':
        print(q)
        word.append(q.split(' ')[0])
    else:
        word.append('others')

# %%
np.unique(np.array(word), return_counts=True, return_index=True)

# %%
uq_word, qid, ct = np.unique(np.array(word), return_counts=True, return_index=True)

# %%
for i, w in enumerate(uq_word):
    if ct[i] == 1:
        print(at_db_train[qid[i]]['question'], at_db_train[qid[i]]['category'])

# %%
print([uq_word[x] for x in range(len(uq_word)) if ct[x]==1])

# %%
print([uq_word[x] for x in range(len(uq_word)) if ct[x]==2])

# %%
print([uq_word[x] for x in range(len(uq_word)) if ct[x]==3])

# %%
print([uq_word[x] for x in range(len(uq_word)) if ct[x]==4])

# %%
len(np.unique(types))

# %%
t, c = np.unique(types, return_counts=True)
ind = np.argsort(-c)

# %%
[f'{t[ind[i]]}: {c[ind[i]]}' for i in range(len(t))]

# %% [markdown]
# ### Distribution of all possible answer types

# %%
plt.plot(c[ind])

# %% [markdown]
# #### Possible number of answer types for a particular question

# %%
np.unique(num_types)

# %%
at_db_train[np.where(num_types==627)[0][1]]

# %%
at_db_train[np.where(num_types==627)[0][2]]

# %%
at_db_train[np.where(num_types==93)[0][0]]

# %%
at_db_train[1:25]

# %%
len(np.where(num_types==1)[0])

# %%
len(np.where(num_types==627)[0])

# %%
len(np.where(num_types==93)[0])

# %% [markdown]
# ### after removing multiple answer types for a particular question

# %%
categories = []
num_types = []
types = []

for entry in at_db_train:
    categories.append(entry['category'])
    num_types.append(len(np.unique(entry['type'])))
    types.append(np.unique(entry['type']))

types_merged = [a for sublist in types for a in sublist]
num_types = np.array(num_types)

# %%
t, c = np.unique(types_merged, return_counts=True)
ind = np.argsort(-c)

# %% [markdown]
# ### New distribution of answer types

# %%
plt.plot(c[ind])

# %%
np.unique(num_types)

# %%
[len(np.where(num_types==x)[0]) for x in np.unique(num_types)]

# %% [markdown]
# ### 21 Aug 2022

# %%
categories = []
num_types = []
types = []

for entry in at_db_train:
    categories.append(entry['category'])
    num_types.append(len(np.unique(entry['type'])))
    types.append(np.unique(entry['type']))
    
categories = np.array(categories)
num_types = np.array(num_types)
types = np.array(types, dtype=object)
#types = [a for sublist in types for a in sublist]

# %%
len(categories)

# %%
len(types)

# %%
types.shape

# %%
print(np.sum(categories=='boolean'))
print(np.sum(categories=='literal'))
print(np.sum(categories=='resource'))

# %%
resource_types = types[np.where(categories=='resource')[0]]

# %%
len(np.unique([x for sublist in resource_types for x in sublist]))

# %%
xx = np.unique(np.array([len(resource_types[x]) for x in range(len(resource_types))]))

# %%
yy = [np.sum([True for t in resource_types if len(t)==num]) for num in xx]

# %%
plt.scatter(xx,yy)
plt.grid('on')
plt.xlabel('Number of resource types for a question')
plt.ylabel('Number of questions')
plt.show()

# %%
resource_types[1]
